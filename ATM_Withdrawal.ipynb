# %% [markdown]
# <a href="https://colab.research.google.com/github/KedarDebadwar/python_series/blob/main/ATM_Withdrawal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A = int(input())
if((A % 500) % 200 == 0):
  print("Allow withdrawal", A)
else:
  print("Can't allow withdrwal as ATM has 500 & 200 rupee notes.")
# Out:
# 700
# Allow withdrawal 700

# %%
A = int(input())
print((A % 500) % 200)
# Out:
# 500
# 0
