# %% [markdown]
# <a href="https://colab.research.google.com/github/KedarDebadwar/python_series/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2024-08-28 01:40:11--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 108.177.11.102, 108.177.11.101, 108.177.11.138, ...
# Connecting to drive.google.com (drive.google.com)|108.177.11.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download [following]
# --2024-08-28 01:40:11--  https://drive.usercontent.google.com/download?id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 173.194.212.132, 2607:f8b0:400c:c11::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|173.194.212.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [application/octet-stream]
# Saving to: ‘mckinsey.csv’
#
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('mckinsey.csv')
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
#Add rows --> 1. concat() 2. loc/iloc

# %%
new_row = {'country': 'India', 'year': 2000,'population':13500000, 'continent': "Asia", 'life_exp':37.08, 'gdp_cap':900.23}

# %%
df = pd.concat([df,pd.DataFrame([new_row])],ignore_index=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
#
# [1705 rows x 6 columns]

# %%
pd.concat([df,pd.DataFrame([new_row])],ignore_index=False) #comparison
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 0           India  2000    13500000      Asia    37.080  900.230000
#
# [1706 rows x 6 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1705, step=1)

# %%
len(df.index)
# Out:
# 1705

# %%
new_row = {'country': 'India', 'year': 2000,'population':13500000, 'continent': "Asia", 'life_exp':37.08, 'gdp_cap':900.23}
new_row_val = list(new_row.values())
new_row_val
# Out:
# ['India', 2000, 13500000, 'Asia', 37.08, 900.23]

# %%
df.loc[len(df.index)] = new_row_val
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
#
# [1706 rows x 6 columns]

# %%
len(df.index)
# Out:
# 1706

# %%
#iloc

# %%
df.iloc[len(df.index)] = ['Japan', 1000, 1350000, 'Asia', 37.08, 100.23]
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-e2f8a212c90f> in <cell line: 1>()
# ----> 1 df.iloc[len(df.index)] = ['Japan', 1000, 1350000, 'Asia', 37.08, 100.23]
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     880             key = com.apply_if_callable(key, self.obj)
#     881         indexer = self._get_setitem_indexer(key)
# --> 882         self._has_valid_setitem_indexer(key)
#     883
#     884         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1606             elif is_integer(i):
#    1607                 if i >= len(ax):
# -> 1608                     raise IndexError("iloc cannot enlarge its target object")
# ...

# %%
df.iloc[len(df.index)-1] = ['Japan', 1000, 1350000, 'Asia', 37.08, 100.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1706 rows x 6 columns]

# %%
#drop()

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1706 rows x 6 columns]

# %%
df.drop(3,axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1705 rows x 6 columns]

# %%
df = df.drop(3,axis=0)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1705 rows x 6 columns]

# %%
df.loc[4]
# Out:
# country       Afghanistan
# year                 1972
# population       13079460
# continent            Asia
# life_exp           36.088
# gdp_cap        739.981106
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# country       Afghanistan
# year                 1977
# population       14880372
# continent            Asia
# life_exp           38.438
# gdp_cap         786.11336
# Name: 5, dtype: object

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1705 rows x 6 columns]

# %%
df.drop([1,2,4],axis=0)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 5     Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6     Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7     Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8     Afghanistan  1992    16317921      Asia    41.674  649.341395
# ...           ...   ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      Asia    37.080  900.230000
# 1705        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1702 rows x 6 columns]

# %%
#reset the index

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1705 rows x 6 columns]

# %%
#example : Impact of drop on explicit indexes

df8 = pd.DataFrame({
    'A': [10, 20, 30],
    'B': [40, 50, 60]
}, index=['x', 'y', 'z'])

print("Original DataFrame:")
print(df8)
# Out:
# Original DataFrame:
#     A   B
# x  10  40
# y  20  50
# z  30  60

# %%
df_reset_without_drop = df8.reset_index()

print("\nDataFrame after reset_index without drop=True:")
print(df_reset_without_drop)
# Out:
# DataFrame after reset_index without drop=True:
#   index   A   B
# 0     x  10  40
# 1     y  20  50
# 2     z  30  60

# %%
df_reset_with_drop = df8.reset_index(drop=True)

print("\nDataFrame after reset_index with drop=True:")
print(df_reset_with_drop)
# Out:
# DataFrame after reset_index with drop=True:
#     A   B
# 0  10  40
# 1  20  50
# 2  30  60

# %%
#implicit case:

# %%
df4 = pd.DataFrame({
    'A': [10, 20, 30],
    'B': [40, 50, 60]
})

print("Original DataFrame with implicit index:")
print(df4)
# Out:
# Original DataFrame with implicit index:
#     A   B
# 0  10  40
# 1  20  50
# 2  30  60

# %%
df_reset = df4.reset_index(drop=True)

print("\nDataFrame after reset_index:")
print(df_reset)
# Out:
# DataFrame after reset_index:
#     A   B
# 0  10  40
# 1  20  50
# 2  30  60

# %%
df_reset = df4.reset_index()
df_reset
# Out:
#    index   A   B
# 0      0  10  40
# 1      1  20  50
# 2      2  30  60

# %%
#Handling duplicate records

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
#
# [1705 rows x 6 columns]

# %%
df.loc[len(df.index)] = ['India', 2000, 13500000, 'Asia', 37.08, 900.23]
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000, 'Asia', 80.00,500.00]
df.loc[len(df.index)] = ['Sri Lanka',2022 ,130000000, 'Asia', 80.00,500.00]
df.loc[len(df.index)] = ['India',2000 ,13500000, 'Asia', 80.00,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1704    False
# 1705     True
# 1706    False
# 1707     True
# 1708    False
# Length: 1709, dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1705      India  2000    13500000      Asia     37.08   900.23
# 1707  Sri Lanka  2022   130000000      Asia     80.00   500.00

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
#keep argument of drop_duplicates()

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.drop_duplicates(keep='first') #default
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1703        India  2000    13500000      Asia    37.080  900.230000
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.drop_duplicates(keep='last')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.drop_duplicates(keep=False)
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1700     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1701     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1702     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1705 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.drop_duplicates(subset=['country'],keep='first')
# Out:
#                  country  year  population continent  life_exp      gdp_cap
# 0            Afghanistan  1952     8425333      Asia    28.801   779.445314
# 11               Albania  1952     1282697    Europe    55.230  1601.056136
# 23               Algeria  1952     9279525    Africa    43.077  2449.008185
# 35                Angola  1952     4232095    Africa    30.015  3520.610273
# 47             Argentina  1952    17876956  Americas    62.485  5911.315053
# ...                  ...   ...         ...       ...       ...          ...
# 1643             Vietnam  1952    26246839      Asia    40.412   605.066492
# 1655  West Bank and Gaza  1952     1030585      Asia    43.160  1515.592329
# 1667         Yemen, Rep.  1952     4963829      Asia    32.548   781.717576
# 1679              Zambia  1952     2672000    Africa    42.038  1147.388831
# 1691            Zimbabwe  1952     3080907    Africa    48.451   406.884115
#
# [142 rows x 6 columns]

# %%
#Quiz 1

data = {'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
        'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
        'C': ['small', 'large', 'large', 'small', 'small', 'large', 'large', 'small'],
        'D': [1, 2, 2, 3, 3, 4, 5, 6]}

df10 = pd.DataFrame(data)

print(sum(df10.duplicated(subset=['A', 'B'])))
# Out:
# 2

# %%
df10
# Out:
#      A      B      C  D
# 0  foo    one  small  1
# 1  bar    one  large  2
# 2  foo    two  large  2
# 3  bar  three  small  3
# 4  foo    two  small  3
# 5  bar    two  large  4
# 6  foo    one  large  5
# 7  foo  three  small  6

# %%
df10.duplicated(subset=['A', 'B'])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
sum(df10.duplicated(subset=['A', 'B']))
# Out:
# 2

# %%
#False --> 0
#True --> 1

# %%
#Slicing the DF (rows and columns)
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.iloc[0:4,0:3]
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1972    13079460

# %%
df.loc[1:5, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-494208dc7680> in <cell line: 1>()
# ----> 1 df.loc[1:5, 1:4]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1145             if self._is_scalar_access(key):
#    1146                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147             return self._getitem_tuple(key)
#    1148         else:
#    1149             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1337             return self._multi_take(tup)
#    1338
# -> 1339         return self._getitem_tuple_same_dim(tup)
#    1340
#    1341     def _get_label(self, label, axis: AxisInt):
#
# ...

# %%
df.loc[1:5, ['country','life_exp']]
# Out:
#        country  life_exp
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    36.088
# 4  Afghanistan    38.438
# 5  Afghanistan    39.854

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.loc[1:5, 'year':'life_exp']
# Out:
#    year  population continent  life_exp
# 1  1957     9240934      Asia    30.332
# 2  1962    10267083      Asia    31.997
# 3  1972    13079460      Asia    36.088
# 4  1977    14880372      Asia    38.438
# 5  1982    12881816      Asia    39.854

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 4     Afghanistan  1977    14880372      Asia    38.438  786.113360
# ...           ...   ...         ...       ...       ...         ...
# 1704        Japan  1000     1350000      Asia    37.080  100.230000
# 1705        India  2000    13500000      Asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000  500.000000
# 1708        India  2000    13500000      Asia    80.000  900.230000
#
# [1709 rows x 6 columns]

# %%
df.iloc[[0,10,100],[0,2,3]]
# Out:
#          country  population continent
# 0    Afghanistan     8425333      Asia
# 10   Afghanistan    31889923      Asia
# 100   Bangladesh    80428306      Asia

# %%
df.iloc[1:10:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
df.loc[1:10:2]
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 3  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  2002    25268405      Asia    42.129  726.734055

# %%
#Pandas inbuilt operations
#Aggregate functions

# %%
le = df['life_exp']

# %%
le
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       36.088
# 4       38.438
#          ...
# 1704    37.080
# 1705    37.080
# 1706    80.000
# 1707    80.000
# 1708    80.000
# Name: life_exp, Length: 1709, dtype: float64

# %%
le.mean()
# Out:
# 59.486053060269164

# %%
le.sum()
# Out:
# 101661.66468

# %%
le.count()
# Out:
# 1709

# %%
le.sum()/le.count()
# Out:
# 59.486053060269164

# %%
#Sorting values

# %%
df.sort_values(['life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1709 rows x 6 columns]

# %%
df.sort_values(['life_exp'],ascending=False)
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 801              Japan  2002   127065841      Asia    82.000  28604.591900
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 1486       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1291            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1709 rows x 6 columns]

# %%
df.sort_values(['year','life_exp'])
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1704             Japan  1000     1350000      Asia    37.080    100.230000
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 551             Gambia  1952      284320    Africa    30.000    485.230659
# 35              Angola  1952     4232095    Africa    30.015   3520.610273
# 1343      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 694            Iceland  2007      301931    Europe    81.757  36180.789190
# 670   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2007   127467972      Asia    82.603  31656.068060
# 1706         Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1707         Sri Lanka  2022   130000000      Asia    80.000    500.000000
#
# [1709 rows x 6 columns]

# %%
df.sort_values(['year','life_exp'], ascending=[False,True])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1706    Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1707    Sri Lanka  2022   130000000      Asia    80.000    500.000000
# 1462    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1042   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1690       Zambia  2007    11746035    Africa    42.384   1271.211593
# ...           ...   ...         ...       ...       ...           ...
# 1463       Sweden  1952     7124673    Europe    71.860   8527.844662
# 1079  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 683       Iceland  1952      147962    Europe    72.490   7267.688428
# 1139       Norway  1952     3327728    Europe    72.670  10095.421720
# 1704        Japan  1000     1350000      Asia    37.080    100.230000
#
# [1709 rows x 6 columns]

# %%
#Concatenating dfs
users = pd.DataFrame({"userid":[1, 2, 3], "name":["sharadh", "shahid", "khusalli"]})
users
# Out:
#    userid      name
# 0       1   sharadh
# 1       2    shahid
# 2       3  khusalli

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users,msgs])
# Out:
#    userid      name        msg
# 0       1   sharadh        NaN
# 1       2    shahid        NaN
# 2       3  khusalli        NaN
# 0       1       NaN        hmm
# 1       1       NaN       acha
# 2       2       NaN  theek hai
# 3       4       NaN       nice

# %%
pd.concat([users, msgs], ignore_index=True)
# Out:
#    userid      name        msg
# 0       1   sharadh        NaN
# 1       2    shahid        NaN
# 2       3  khusalli        NaN
# 3       1       NaN        hmm
# 4       1       NaN       acha
# 5       2       NaN  theek hai
# 6       4       NaN       nice

# %%
pd.concat([users, msgs], axis=1)
# Out:
#    userid      name  userid        msg
# 0     1.0   sharadh       1        hmm
# 1     2.0    shahid       1       acha
# 2     3.0  khusalli       2  theek hai
# 3     NaN       NaN       4       nice

# %%
#Merging dataframes

# %%
users.merge(msgs, on='userid') #inner
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai

# %%
users.merge(msgs, on="userid", how="outer")
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN
# 4       4       NaN       nice

# %%
users.merge(msgs, on="userid", how="left")
# Out:
#    userid      name        msg
# 0       1   sharadh        hmm
# 1       1   sharadh       acha
# 2       2    shahid  theek hai
# 3       3  khusalli        NaN

# %%
users.merge(msgs, on="userid", how="right")
# Out:
#    userid     name        msg
# 0       1  sharadh        hmm
# 1       1  sharadh       acha
# 2       2   shahid  theek hai
# 3       4      NaN       nice

# %%
users.rename(columns = {"userid": "id"}, inplace=True)
users
# Out:
#    id      name
# 0   1   sharadh
# 1   2    shahid
# 2   3  khusalli

# %%
users.merge(msgs, left_on="id", right_on="userid")
# Out:
#    id     name  userid        msg
# 0   1  sharadh       1        hmm
# 1   1  sharadh       1       acha
# 2   2   shahid       2  theek hai

# %%
import pandas as pd
df1 = pd.DataFrame({'A':[10,30], 'B':[20,40], 'C':[30, 60]})
df2 = pd.DataFrame({'A':[10,30], 'C':[30, 60]})
df2.merge(df1, on = 'A', how = 'outer')
# Out:
#     A  C_x   B  C_y
# 0  10   30  20   30
# 1  30   60  40   60

# %%
df2.merge(df1, on = 'A', how = 'outer').shape
# Out:
# (2, 4)

# %%
df1
# Out:
#     A   B   C
# 0  10  20  30
# 1  30  40  60

# %%
df2
# Out:
#     A   C
# 0  10  30
# 1  30  60

# %%
import pandas as pd

data = {
    'Country': ['Afghanistan', 'Australia', 'Brazil', 'China', 'France', 'India', 'United States'],
    'Year':  [1952, 1957, 1962, 1957, 1957, 1952, 1957],
    'Population':  [8425333.0, 9712569.0, 76039390.0, 637408000.0, 44310863.0, 372000000.0,  171984000.0],
    'Continent':  ['Asia', 'Oceania', 'Americas', 'Asia', 'Europe', 'Asia', 'Americas']
}

df_pb = pd.DataFrame(data)

# %%
df_pb
# Out:
#          Country  Year   Population Continent
# 0    Afghanistan  1952    8425333.0      Asia
# 1      Australia  1957    9712569.0   Oceania
# 2         Brazil  1962   76039390.0  Americas
# 3          China  1957  637408000.0      Asia
# 4         France  1957   44310863.0    Europe
# 5          India  1952  372000000.0      Asia
# 6  United States  1957  171984000.0  Americas

# %%
def population_df(df_pb):
    '''df is a dataframe with columns ['Country', 'Year', 'Population', 'Continent']
       Output -> A dataframe is expected to be returned.'''

    # Filter the dataframe for records greater than 10 million
    df_filtered = df_pb[df_pb['Population'] > 10000000]

    # Sort the filtered dataframe first by year, then by population
    df_sorted = df_filtered.sort_values(by=['Year', 'Population'], ascending=[True, True])

    # Don't modify this line of code
    return df_sorted.reset_index(drop = True)

# %%
#data=eval(input())
final_df = population_df(pd.DataFrame(data, columns=['Country', 'Year', 'Population','Continent']))
print(final_df)
# Out:
#          Country  Year   Population Continent
# 0          India  1952  372000000.0      Asia
# 1         France  1957   44310863.0    Europe
# 2  United States  1957  171984000.0  Americas
# 3          China  1957  637408000.0      Asia
# 4         Brazil  1962   76039390.0  Americas
